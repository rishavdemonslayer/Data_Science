# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for Control-7 days
plants = ['Methi', 'Pudhina', 'Tomato']
heights_consortium = [3.63, 7.73, 6.36]
std_consortium = [0.076, 0.205, 0.376]
heights_fruit = [9.37, 8.13, 6.7]
std_fruit = [0.197, 0.07, 0.02]
heights_parthenium = [3.92, 8.18, 7.15]
std_parthenium = [0.171, 0.132, 0.094]

leaves_consortium = [2.33, 4, 2.33]
leaves_std_consortium = [0.577, 1, 0.577]
leaves_fruit = [2.33, 4.33, 2.33]
leaves_std_fruit = [0.577, 1.154, 0.577]
leaves_parthenium = [3, 3.33, 2.33]
leaves_std_parthenium = [1, 0.577, 0.577]

# Data for Control-14 days (example data)
heights_consortium_14 = [4.00, 8.23, 7.00]
std_consortium_14 = [0.100, 0.220, 0.400]
heights_fruit_14 = [10.00, 9.00, 7.50]
std_fruit_14 = [0.220, 0.090, 0.025]
heights_parthenium_14 = [4.50, 9.00, 8.00]
std_parthenium_14 = [0.190, 0.140, 0.100]

leaves_consortium_14 = [3, 5, 3]
leaves_std_consortium_14 = [0.600, 1.200, 0.600]
leaves_fruit_14 = [3.5, 5.5, 3.5]
leaves_std_fruit_14 = [0.600, 1.300, 0.600]
leaves_parthenium_14 = [4, 4.5, 3.5]
leaves_std_parthenium_14 = [1.1, 0.600, 0.600]

# Data for Test-7 days (example data)
heights_consortium_test7 = [5.00, 9.00, 8.00]
std_consortium_test7 = [0.150, 0.230, 0.500]
heights_fruit_test7 = [11.00, 9.50, 8.00]
std_fruit_test7 = [0.250, 0.100, 0.050]
heights_parthenium_test7 = [6.00, 10.00, 8.50]
std_parthenium_test7 = [0.200, 0.150, 0.120]

leaves_consortium_test7 = [4, 6, 4]
leaves_std_consortium_test7 = [0.650, 1.250, 0.650]
leaves_fruit_test7 = [4.5, 6.5, 4.5]
leaves_std_fruit_test7 = [0.650, 1.350, 0.650]
leaves_parthenium_test7 = [5, 5.5, 4.5]
leaves_std_parthenium_test7 = [1.2, 0.650, 0.650]

# Data for Test-14 days (example data)
heights_consortium_test14 = [5.50, 10.00, 9.00]
std_consortium_test14 = [0.200, 0.250, 0.600]
heights_fruit_test14 = [12.00, 10.00, 9.00]
std_fruit_test14 = [0.300, 0.150, 0.075]
heights_parthenium_test14 = [7.00, 11.00, 9.50]
std_parthenium_test14 = [0.250, 0.180, 0.140]

leaves_consortium_test14 = [5, 7, 5]
leaves_std_consortium_test14 = [0.700, 1.300, 0.700]
leaves_fruit_test14 = [5.5, 7.5, 5.5]
leaves_std_fruit_test14 = [0.700, 1.400, 0.700]
leaves_parthenium_test14 = [6, 6.5, 5.5]
leaves_std_parthenium_test14 = [1.3, 0.700, 0.700]

# Bar width and X positions for the groups
bar_width = 0.2
r1 = np.arange(len(plants))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Function to plot bar graph with blue shades
def plot_bar_graph(heights1, heights2, heights3, std1, std2, std3, ylabel, title):
    plt.figure(figsize=(10,6))
    plt.bar(r1, heights1, width=bar_width, yerr=std1, label='Consortium Vermicompost', capsize=5, color='#ffa500') # Dark blue
    plt.bar(r2, heights2, width=bar_width, yerr=std2, label='Fruitwaste Vermicompost', capsize=5, color='#006d5b') #medium blue
    plt.bar(r3, heights3, width=bar_width, yerr=std3, label='Parthenium Vermicompost', capsize=5, color='#64b5f6') # Light blue

    plt.xlabel('Plants', fontsize=12)
    plt.ylabel(ylabel, fontsize=12)
    plt.title(title, fontsize=14)
    plt.xticks([r + bar_width for r in range(len(plants))], plants)
    plt.legend()
    plt.tight_layout()
    plt.show()

# Heights (Control-7 days)
plot_bar_graph(heights_consortium, heights_fruit, heights_parthenium,
               std_consortium, std_fruit, std_parthenium,
               'Heights (cm)', 'Plant Heights (Control-7 days)')

# Number of Leaves (Control-7 days)
plot_bar_graph(leaves_consortium, leaves_fruit, leaves_parthenium,
               leaves_std_consortium, leaves_std_fruit, leaves_std_parthenium,
               'Number of Leaves', 'Number of Leaves (Control-7 days)')

# Heights (Control-14 days)
plot_bar_graph(heights_consortium_14, heights_fruit_14, heights_parthenium_14,
               std_consortium_14, std_fruit_14, std_parthenium_14,
               'Heights (cm)', 'Plant Heights (Control-14 days)')

# Number of Leaves (Control-14 days)
plot_bar_graph(leaves_consortium_14, leaves_fruit_14, leaves_parthenium_14,
               leaves_std_consortium_14, leaves_std_fruit_14, leaves_std_parthenium_14,
               'Number of Leaves', 'Number of Leaves (Control-14 days)')

# Heights (Test-7 days)
plot_bar_graph(heights_consortium_test7, heights_fruit_test7, heights_parthenium_test7,
               std_consortium_test7, std_fruit_test7, std_parthenium_test7,
               'Heights (cm)', 'Plant Heights (Test-7 days)')

# Number of Leaves (Test-7 days)
plot_bar_graph(leaves_consortium_test7, leaves_fruit_test7, leaves_parthenium_test7,
               leaves_std_consortium_test7, leaves_std_fruit_test7, leaves_std_parthenium_test7,
               'Number of Leaves', 'Number of Leaves (Test-7 days)')

# Heights (Test-14 days)
plot_bar_graph(heights_consortium_test14, heights_fruit_test14, heights_parthenium_test14,
               std_consortium_test14, std_fruit_test14, std_parthenium_test14,
               'Heights (cm)', 'Plant Heights (Test-14 days)')

# Number of Leaves (Test-14 days)
plot_bar_graph(leaves_consortium_test14, leaves_fruit_test14, leaves_parthenium_test14,
               leaves_std_consortium_test14, leaves_std_fruit_test14, leaves_std_parthenium_test14,
               'Number of Leaves', 'Number of Leaves (Test-14 days)')
